# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import levene, ttest_ind, mannwhitneyu, chi2_contingency
import statsmodels.api as sma
import statsmodels.stats as smst
from itertools import chain  # list unpacking

# %%
# Test equality of variances

def var_chk(ser1, ser2):
    stats, bf = levene(ser1, ser2, center='median')
    return round(bf, 3)

# %%
# Test normality

def norm_chk(ser):
    norm = smst.diagnostic.lilliefors(ser, pvalmethod='approx')[1]
    return round(norm, 3)

# %%
# Test two series for variance equality and normality; choose and apply compartible test

def t_test(ser1, ser2, parameter):
    
    # Test the conditions
    norm1, norm2 = norm_chk(ser1), norm_chk(ser2)  # p-values of Lilliefors tests
    bf = var_chk(ser1, ser2)  # p-value of Brown-Forsithe test
    normality = norm1 >= 0.05 and norm2 >= 0.05  # both samples are normal
    var_eq = bf >= 0.05  # variances of samples are equal
    
    if var_eq and normality:
        t = ttest_ind(ser1, ser2)  # Student's t-test
        test = '2-сторонний t-тест Стьюдента'
        
    elif not var_eq and normality:
        t = ttest_ind(ser1, ser2, equal_var = False)  # Welch t-test
        test = '2-сторонний t-тест Уэлча'
    
    elif not normality:
        t = mannwhitneyu(ser1, ser2)  # Mann-Whitney test
        test = 'Тест Манна-Уитни'
    
    return [t[0], round(t[1], 3), test, norm1, norm2, bf]

# %%
# Plot the histograms and quantille-quantille

def norm_plot(ser1, ser2, parameter):
    
    group = ['_Здор', '_Бол']
    
    for s in range(2):
        ser = [ser1, ser2][s]
    
        # plot histogram of series
        plt.hist(ser)
        plt.savefig(parameter[:5] + group[s] + '_hist.png')
        plt.clf()
    
        # plot q-q plot of series
        fig = sma.qqplot(ser, fit=True, line="45")
        plt.savefig(parameter[:5] + group[s] + '_qq_plot.png')
        plt.clf()

# %%
# Fill NaN values by sample medians

def median_fill(ser):
    m = ser.median()
    for s in range(len(ser)):
        if np.isnan(ser[s]): 
            ser.loc[s] = m
    return ser

# %%
# Compute odds ratio with confidence intervals for two-by-two table

def odds_ratio(group1, group2):
    a, b, c, d = group1[0], group1[1], group2[0], group2[1]
    o_r = (a / b) / (c / d)  # odds ratio
    ci_low = np.exp(np.log(o_r) - 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # lower confidence interval
    ci_up = np.exp(np.log(o_r) + 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # Upper confidence interval
    
    return str(round(o_r, 2)) + ' (CI ' + str(round(ci_low, 2)) + '–' + str(round(ci_up, 2)) + ')'

# %%
# Plot histogram of numbers for two-by-two table

def barplot(hlth, dis, name='barplot'):
    x1 = ['Неболевшие', 'Реконвалесценты']

    y1 = [hlth[0], dis[0]]  #  event
    y2 = [hlth[1], dis[1]]  # no event


    fig, ax = plt.subplots()

    ax.bar(x1, y1, width=0.8)
    ax.bar(x1, y2, bottom = y1, width=0.8)

    fig.set_figwidth(7)    #  ширина и
    fig.set_figheight(4)    #  высота "Figure"
    fig.set_facecolor('floralwhite')
    ax.set_facecolor('seashell')
    plt.title(name)
    plt.legend(['Да', 'Нет'], loc='upper left')

    plt.show()
    # plt.savefig(name + '.png')
    plt.clf()

# %%
def chi2_2x2(group1, group2):
    stat = round(chi2_contingency((group1, group2), correction=False)[0], 2)
    p_val = round(chi2_contingency((group1, group2), correction=False)[1], 3)
    return [stat, p_val]

# %%
df = pd.read_csv('C:/Kotomin/StatWorks/Covid/Database.csv', sep='\t')

# %%
# patients that had no COVID-19 at the time of screeneng
hlth = df[df['COVID-19'] == 'нет'].reset_index(drop=True)

# patients that had COVID-19 at the time of screeneng
dis = df[df['COVID-19'] == 'да'].reset_index(drop=True)

# %%
parametres = df.columns.tolist()

# %% [markdown]
# ## Демографические и антропометрические данные

# %%
dem_param = [parametres[3]] + parametres[9:12]

# %%
descr_hlth = hlth[dem_param[0]].astype({'Возраст': float})
descr_hlth = round(descr_hlth.describe(), 2)
descr_dis = dis[dem_param[0]].astype({'Возраст': float})
descr_dis = round(descr_dis.describe(), 2)

for p in dem_param[1:]:
    d_hlth, d_dis = round(hlth[p].describe(), 2), round(dis[p].describe(), 2)
    descr_hlth = pd.concat([descr_hlth, d_hlth], axis=1)
    descr_dis = pd.concat([descr_dis, d_dis], axis=1)

# %% [markdown]
# Неболевшие

# %%
descr_hlth
# Out:
#        Возраст    Рост    Вес    ИМТ
# count    62.00   62.00  62.00  62.00
# mean      9.11  129.94  31.76  17.78
# std       4.32   23.56  13.85   2.45
# min       2.00   83.00  12.00  13.00
# 25%       5.00  107.00  19.00  15.98
# 50%      10.00  135.50  30.50  17.55
# 75%      12.75  148.25  40.00  19.88
# max      17.00  166.00  64.00  25.00

# %% [markdown]
# Реконвалесценты

# %%
descr_dis
# Out:
#        Возраст    Рост     Вес     ИМТ
# count   201.00  200.00  200.00  200.00
# mean     10.29  137.24   36.24   17.99
# std       5.04   26.42   16.12    3.11
# min       0.17   58.00    5.00   11.50
# 25%       6.00  124.00   22.00   15.90
# 50%      11.00  146.50   39.00   17.80
# 75%      15.00  156.25   49.00   20.10
# max      17.00  174.00   70.00   27.00

# %% [markdown]
# ## Анализ континуальных количественных переменных (continuous variables)

# %%
parametres.index('эозинофилы')  # Придумать, что с ними делать
# Out:
# 86

# %%
#Descriptive statistics for continuous variables

cont_param = parametres[45:47] + parametres[81:85] + parametres[87:91]

descr_hlth = round(hlth[cont_param[0]].describe(), 3)
descr_dis = round(dis[cont_param[0]].describe(), 3)

for p in cont_param[1:]:
    d_hlth, d_dis = round(hlth[p].describe(), 3), round(dis[p].describe(), 3)
    descr_hlth = pd.concat([descr_hlth, d_hlth], axis=1)
    descr_dis = pd.concat([descr_dis, d_dis], axis=1)

# %% [markdown]
# Неболевшие

# %%
descr_hlth
# Out:
#        Среднее количество заболеваний ОРВИ в год  \
# count                                     62.000
# mean                                       2.726
# std                                        1.203
# min                                        1.000
# 25%                                        2.000
# 50%                                        2.500
# 75%                                        3.000
# max                                        6.000
#
#        Количество заболеваний ОРВИ у ребенка за 2020 год  гемоглобин Г/л  \
# count                                             62.000          62.000
# mean                                               1.919         123.774
# std                                                0.685           9.589
# min                                                1.000          90.000
# 25%                                                1.250         120.750
# 50%                                                2.000         124.000
# 75%                                                2.000         130.000
# max                                                4.000         142.000
#
#        эритроциты  лейкоциты  тромбоциты  нейтрофилы  лимфоциты  моноциты  \
# count      62.000     62.000      62.000      62.000     62.000    62.000
# mean        4.403      8.203     298.694      48.613     41.613     6.855
# std         0.706      3.164     110.013      14.296     15.837     2.745
# min         2.450      2.700     115.000      20.000     11.000     1.000
# 25%         4.000      6.125     225.000      36.000     29.000     5.000
# 50%         4.450      7.700     260.000      47.500     42.000     7.000
# 75%         4.855     10.200     360.000      63.000     54.000     9.000
# max         6.100     15.600     584.000      74.000     75.000    14.000
#
#           СОЭ
# count  62.000
# mean    9.145
# std     3.328
# min     4.000
# 25%     7.000
# 50%     9.000
# 75%    11.000
# max    21.000

# %% [markdown]
# Реконвалесценты

# %%
descr_dis
# Out:
#        Среднее количество заболеваний ОРВИ в год  \
# count                                    199.000
# mean                                       3.151
# std                                        1.131
# min                                        1.000
# 25%                                        2.000
# 50%                                        3.000
# 75%                                        4.000
# max                                        8.000
#
#        Количество заболеваний ОРВИ у ребенка за 2020 год  гемоглобин Г/л  \
# count                                            200.000         201.000
# mean                                               2.550         118.139
# std                                                0.837          12.964
# min                                                1.000          11.000
# 25%                                                2.000         112.000
# 50%                                                2.000         120.000
# 75%                                                3.000         125.000
# max                                                5.000         154.000
#
#        эритроциты  лейкоциты  тромбоциты  нейтрофилы  лимфоциты  моноциты  \
# count     201.000    201.000      201.00     201.000    201.000   201.000
# mean        4.191      7.955      235.95      48.368     43.960     6.403
# std         0.673      2.718       86.53      15.484     15.042     2.363
# min         2.800      3.900      100.00      11.000      7.000     3.000
# 25%         3.700      5.600      180.00      37.000     33.000     6.000
# 50%         4.100      7.600      224.00      50.000     43.000     6.000
# 75%         4.700     10.200      260.00      59.000     56.000     6.000
# max         5.800     13.600      450.00      86.000     78.000    20.000
#
#            СОЭ
# count  201.000
# mean     6.418
# std      4.217
# min      2.000
# 25%      4.000
# 50%      5.000
# 75%      8.000
# max     23.000

# %%
# Table of results for continuous variables
cont_result = pd.DataFrame(index=cont_param, columns=['Тестовая статистика', 'p-value', 'Вид теста', 'Lilliefors p здор.', 'Lilliefors p бол.', 'p variances (Brown-Forsithe test)'])

# Fill the table
for p in cont_param:
    
    # fill the skipped values by medians
    hlth.loc[:, p] = median_fill(hlth.loc[:, p])
    dis.loc[:, p] = median_fill(dis.loc[:, p])
    
    # table filling
    cont_result.loc[p] = t_test(hlth[p], dis[p], p)

# %%
# histogram and qq plot
for p in cont_param:
    norm_plot(hlth[p], dis[p], p)
# Out:
# c:\kotomin\soft\python\lib\site-packages\statsmodels\graphics\utils.py:55: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()

# %%
cont_result
# Out:
#                                                   Тестовая статистика p-value  \
# Среднее количество заболеваний ОРВИ в год                      4812.0   0.002
# Количество заболеваний ОРВИ у ребенка за 2020 год              3748.5     0.0
# гемоглобин Г/л                                                 4130.0     0.0
# эритроциты                                                     4967.0   0.008
# лейкоциты                                                      5953.0   0.298
# тромбоциты                                                     3982.0     0.0
# нейтрофилы                                                     6103.5   0.404
# лимфоциты                                                      5618.0   0.121
# моноциты                                                       5281.5   0.028
# СОЭ                                                            2935.0     0.0
#
#                                                           Вид теста  \
# Среднее количество заболеваний ОРВИ в год          Тест Манна-Уитни
# Количество заболеваний ОРВИ у ребенка за 2020 год  Тест Манна-Уитни
# гемоглобин Г/л                                     Тест Манна-Уитни
# эритроциты                                         Тест Манна-Уитни
# лейкоциты                                          Тест Манна-Уитни
# тромбоциты                                         Тест Манна-Уитни
# нейтрофилы                                         Тест Манна-Уитни
# лимфоциты                                          Тест Манна-Уитни
# моноциты                                           Тест Манна-Уитни
# СОЭ                                                Тест Манна-Уитни
#
#                                                   Lilliefors p здор.  \
# Среднее количество заболеваний ОРВИ в год                        0.0
# Количество заболеваний ОРВИ у ребенка за 2020 год                0.0
# гемоглобин Г/л                                                   0.0
# эритроциты                                                     0.097
# лейкоциты                                                       0.03
# тромбоциты                                                     0.001
# нейтрофилы                                                     0.034
# лимфоциты                                                      0.004
# моноциты                                                       0.197
# СОЭ                                                            0.068
#
#                                                   Lilliefors p бол.  \
# Среднее количество заболеваний ОРВИ в год                       0.0
# Количество заболеваний ОРВИ у ребенка за 2020 год               0.0
# гемоглобин Г/л                                                  0.0
# эритроциты                                                      0.0
# лейкоциты                                                       0.0
# тромбоциты                                                      0.0
# нейтрофилы                                                    0.009
# лимфоциты                                                     0.081
# моноциты                                                        0.0
# СОЭ                                                             0.0
#
#                                                   p variances (Brown-Forsithe test)
# Среднее количество заболеваний ОРВИ в год                                     0.138
# Количество заболеваний ОРВИ у ребенка за 2020 год                             0.043
# гемоглобин Г/л                                                                0.088
# эритроциты                                                                    0.662
# лейкоциты                                                                     0.248
# тромбоциты                                                                    0.013
# нейтрофилы                                                                    0.751
# лимфоциты                                                                     0.267
# моноциты                                                                        0.0
# СОЭ                                                                           0.839

# %%
# verticalization of dataframe

vert_df = pd.DataFrame(columns=['Параметр', 'Величина', 'COVID-19'])
for p in cont_param:
    par_df = pd.Series([p for _ in range(len(df))], name='Параметр')  # for categorial scale
    val_df = df[p]  # for continuous scale
    val_df.name = 'Величина'
    three_df = pd.concat([par_df, val_df, df['COVID-19']], axis=1)  # merge 3 columns in block
    vert_df = pd.concat([vert_df, three_df], axis=0)  # merge blocks

# Boxplot
for p in cont_param:
    sns.set_theme(style="ticks")
    f, ax = plt.subplots(figsize=(6, 8))

    # Plot with vertical boxes
    sns.boxplot(data=vert_df[vert_df['Параметр'] == p], x='Параметр', y='Величина', hue='COVID-19', 
                
                orient='v', dodge=True, whis=[2.5, 97.5], width=.2, palette="vlag")

    # Add in points to show each observation
    # sns.stripplot(data=vert_df, x='Параметр', y='Величина', hue='COVID-19', orient='v', size=4, color=".3", linewidth=0)

    # Tweak the visual presentation
    plt.grid(True)
    plt.xticks(rotation=0)
    ax.set(ylabel="Величина показателя", xlabel="")
    sns.despine(trim=True, left=True)
    plt.savefig(p[:7] + '.png')

# %% [markdown]
# ## Дополнительные количественные параметры, которые есть только для 40 человек

# %%
dop_cont_param = parametres[91:95]

descr_hlth = round(hlth[dop_cont_param[0]].describe(), 3)
descr_dis = round(dis[dop_cont_param[0]].describe(), 3)

for p in dop_cont_param[1:]:
    d_hlth, d_dis = round(hlth[p].describe(), 3), round(dis[p].describe(), 3)
    descr_hlth = pd.concat([descr_hlth, d_hlth], axis=1)
    descr_dis = pd.concat([descr_dis, d_dis], axis=1)

# %% [markdown]
# Неболевшие

# %%
descr_hlth
# Out:
#        железо сывороточное  вит Д3    IL-6    IL-10
# count               20.000  20.000  20.000   20.000
# mean                10.368  23.615   3.180   22.989
# std                  4.681  14.896  10.406   52.104
# min                  1.790   7.800   0.040    0.200
# 25%                  7.098  12.000   0.330    0.325
# 50%                 10.495  23.100   0.540    0.750
# 75%                 14.052  26.650   0.805    7.655
# max                 17.620  72.200  47.120  167.980

# %% [markdown]
# Реконвалесценты

# %%
descr_dis
# Out:
#        железо сывороточное  вит Д3    IL-6    IL-10
# count               20.000  20.000  20.000   20.000
# mean                14.375  20.750   3.124   19.661
# std                 10.080  12.654  10.857   78.903
# min                  1.070   9.200   0.040    0.140
# 25%                  6.725  12.875   0.175    0.280
# 50%                 10.015  15.550   0.320    0.650
# 75%                 22.145  22.375   1.000    1.865
# max                 34.460  64.200  48.940  354.380

# %%
dop_cont_result = pd.DataFrame(index=dop_cont_param, columns=['Тестовая статистика', 'p-value', 'Вид теста', 'Lilliefors p здор.', 'Lilliefors p бол.', 'p variances (Brown-Forsithe test)'])
nw_hlth, nw_dis = hlth, dis

# Fill the table
for p in dop_cont_param:
    
    # zeroing previous filters
    nw_hlth, nw_dis = hlth, dis
    
    # filter real values
    nw_hlth = hlth[hlth[p] > 0]
    nw_dis = dis[dis[p] > 0]
    
    # table filling
    dop_cont_result.loc[p] = t_test(nw_hlth[p], nw_dis[p], p)

# %%
# histogram and qq plot
for p in dop_cont_param:
    norm_plot(nw_hlth[p], nw_dis[p], p)

# %%
dop_cont_result
# Out:
#                     Тестовая статистика p-value                 Вид теста  \
# железо сывороточное           -1.612333   0.119  2-сторонний t-тест Уэлча
# вит Д3                            172.5   0.233          Тест Манна-Уитни
# IL-6                              162.5   0.158          Тест Манна-Уитни
# IL-10                             176.0   0.262          Тест Манна-Уитни
#
#                     Lilliefors p здор. Lilliefors p бол.  \
# железо сывороточное              0.468             0.051
# вит Д3                           0.021             0.017
# IL-6                               0.0               0.0
# IL-10                              0.0               0.0
#
#                     p variances (Brown-Forsithe test)
# железо сывороточное                             0.016
# вит Д3                                          0.549
# IL-6                                            0.977
# IL-10                                           0.877

# %%
# verticalization of dataframe

vert_df = pd.DataFrame(columns=['Параметр', 'Величина', 'COVID-19'])
for p in dop_cont_param:
    par_df = pd.Series([p for _ in range(len(df))], name='Параметр')  # for categorial scale
    val_df = df[p]  # for continuous scale
    val_df.name = 'Величина'
    three_df = pd.concat([par_df, val_df, df['COVID-19']], axis=1)  # merge 3 columns in block
    vert_df = pd.concat([vert_df, three_df], axis=0)  # merge blocks

# Boxplot
for p in dop_cont_param:
    sns.set_theme(style="ticks")
    f, ax = plt.subplots(figsize=(6, 8))
    
    # (for log y scale) ax.set_yscale("log")

    # Plot with vertical boxes
    sns.boxplot(data=vert_df[vert_df['Параметр'] == p], x='Параметр', y='Величина', hue='COVID-19', 
                
                orient='v', dodge=True, whis=[2.5, 97.5], width=.2, palette="vlag")

    # Add in points to show each observation
    # sns.stripplot(data=vert_df, x='Параметр', y='Величина', hue='COVID-19', orient='v', size=4, color=".3", linewidth=0)

    # Tweak the visual presentation
    plt.grid(True)
    plt.xticks(rotation=0)
    ax.set(ylabel="Величина показателя", xlabel="")
    sns.despine(trim=True, left=True)
    plt.savefig(p[:7] + '.png')

# %% [markdown]
# ## Категориальные переменные

# %%
# "да"

cat_param_y = parametres[12:14] + [parametres[16]] + [parametres[55]] + [parametres[65]] + [parametres[79]]

# единички

cat_param_03 = parametres[18:27]
cat_param_37 = parametres[27:36]  # старше двух лет, единички
cat_param_7 = parametres[36:45]  # старше шести лет, единички
cat_param_chr = parametres[47:55]  # единички 
cat_param_sym = parametres[67:77] + [parametres[78]]  # единички
cat_param_bas = [parametres[85]]  # единички

# специфические

cat_param_d = parametres[56:60]   # единички, против колонки 58 (не принимает витамин Д)

cat_param_edu = parametres[4:8]  # образовательные учреждения
cat_param_feed = [parametres[17]]  # 4 категории времени вскармливания
cat_param_yn = parametres[62:65] # в колонке ответы "да" или "нет", другие не учитываем
cat_param_male = [parametres[8]]  # Пол - "муж" или ничего
cat_param_time = [parametres[14]]  # Срок родов, 3 категории - "преждевременные", "запоздалые" или ничего
cat_param_birt = [parametres[15]]  # Родоразрешение "самопроизвольное" или "кесарево"

# исключили
cat_param_nochr = [parametres[54]]  # единички означают отсутствие события (нет хронических), пропуски - присутствие
# но по факту данные в таблице неадекватные

# %% [markdown]
# Хронические заболевания и симптомы

# %%
# Dataframe with events

cat_cols = ['Реконвалесценты – да', 'Реконвалесценты – нет', 'Неболевшие – да', 'Неболевшие – нет', 'OR (CI95)', 'Хи-квадрат', 'p-value']
cat_df = pd.DataFrame(columns=cat_cols)


# variables with value only "1"
for p in cat_param_chr + cat_param_sym + cat_param_bas:
    
    # replace str elements with 1
    for i in range(len(dis.loc[:, p])):
        if type(dis.loc[i, p]) == str:
            dis.loc[i, p] = 1
    for i in range(len(hlth.loc[:, p])):
        if type(hlth.loc[i, p]) == str:            
            hlth.loc[i, p] = 1
    
    a = dis.loc[:, p].sum()
    b = len(dis.loc[:, p]) - a
    c = hlth.loc[:, p].sum()
    d = len(hlth.loc[:, p]) - c
    
    if 0 not in [a, b, c, d]:
        res = [int(i) for i  in [a, b, c, d]] + [odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
        cat_df.loc[p] = res
    else:        
        cat_df.loc[p] = [int(i) for i in [a, b, c, d]] + ['', '', '']

# %%
cat_df
# Out:
#                            Реконвалесценты – да Реконвалесценты – нет  \
# Атопический дерматит                          9                   192
# Тубинфецирование                              5                   196
# Заболевание ЖКТ                              12                   189
# Нарушение осанки                              5                   196
# Бронхиальная астма                            2                   199
# ЛОР-заболевания                               8                   193
# Другая патология (указать)                    5                   196
# Нет хронических                             148                    53
# тем37,2-38                                  121                    80
# темп 38,1-39                                 43                   158
# тем39,1-40                                    8                   193
# темп >41                                      0                   201
# Кашель                                       51                   150
# Насморк                                      99                   102
# Заложенность носа                           119                    82
# Потеря обоняния                              36                   165
# Затрудненное дыхание                          6                   195
# першение в горле                             60                   141
# утомляемость                                 59                   142
# базофилы                                      7                   194
#
#                            Неболевшие – да Неболевшие – нет  \
# Атопический дерматит                     3               59
# Тубинфецирование                         0               62
# Заболевание ЖКТ                          0               62
# Нарушение осанки                         1               61
# Бронхиальная астма                       0               62
# ЛОР-заболевания                          6               56
# Другая патология (указать)               4               58
# Нет хронических                          1               61
# тем37,2-38                              10               52
# темп 38,1-39                            10               52
# тем39,1-40                               2               60
# темп >41                                 0               62
# Кашель                                  11               51
# Насморк                                 16               46
# Заложенность носа                       10               52
# Потеря обоняния                          5               57
# Затрудненное дыхание                     0               62
# першение в горле                         8               54
# утомляемость                            55                7
# базофилы                                 0               62
#
#                                            OR (CI95) Хи-квадрат p-value
# Атопический дерматит             0.92 (CI 0.24–3.52)       0.01   0.905
# Тубинфецирование
# Заболевание ЖКТ
# Нарушение осанки                1.56 (CI 0.18–13.58)       0.16   0.687
# Бронхиальная астма
# ЛОР-заболевания                  0.39 (CI 0.13–1.16)       3.05   0.081
# Другая патология (указать)        0.37 (CI 0.1–1.42)       2.25   0.133
# Нет хронических             170.34 (CI 23.04–1259.6)     100.08     0.0
# тем37,2-38                      7.86 (CI 3.78–16.38)      36.81     0.0
# темп 38,1-39                     1.42 (CI 0.66–3.01)       0.82   0.366
# тем39,1-40                       1.24 (CI 0.26–6.02)       0.07   0.786
# темп >41
# Кашель                           1.58 (CI 0.76–3.25)       1.53   0.216
# Насморк                          2.79 (CI 1.48–5.25)      10.59   0.001
# Заложенность носа               7.55 (CI 3.63–15.71)      35.18     0.0
# Потеря обоняния                  2.49 (CI 0.93–6.65)       3.49   0.062
# Затрудненное дыхание
# першение в горле                  2.87 (CI 1.29–6.4)        7.1   0.008
# утомляемость                     0.05 (CI 0.02–0.12)      67.98     0.0
# базофилы

# %% [markdown]
# Детские заболевания

# %%
cat_cols = ['Реконвалесценты – да', 'Реконвалесценты – нет', 'Неболевшие – да', 'Неболевшие – нет', 'OR (CI95)', 'Хи-квадрат', 'p-value']
anamn_df = pd.DataFrame(columns=cat_cols)


# variables with value only "1"

for p in cat_param_03:
    # replace str elements with 1,  younger than 3
    for i in range(len(dis.loc[:, p])):
        if type(dis.loc[i, p]) == str:
            dis.loc[i, p] = 1
    for i in range(len(hlth.loc[:, p])):
        if type(hlth.loc[i, p]) == str:            
            hlth.loc[i, p] = 1
    
    a = dis.loc[:, p].sum()
    b = len(dis.loc[:, p]) - a
    c = hlth.loc[:, p].sum()
    d = len(hlth.loc[:, p]) - c
          
    if 0 not in [a, b, c, d]:
        res = [int(i) for i  in [a, b, c, d]] + [odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
        anamn_df.loc[p] = res
    else:
        anamn_df.loc[p] = [int(i) for i  in [a, b, c, d]] + ['', '', '']


# variables with value only "1", older than 3 and younger than 7

for p in cat_param_37:
    # replace str elements with 1
    for i in range(len(dis.loc[:, p])):
        if type(dis.loc[i, p]) == str:
            dis.loc[i, p] = 1
    for i in range(len(hlth.loc[:, p])):
        if type(hlth.loc[i, p]) == str:            
            hlth.loc[i, p] = 1
    
    a = dis[(dis['Возраст'] >= 3) & (dis['Возраст'] < 7)].loc[:, p].sum()
    b = len(dis[(dis['Возраст'] >= 3) & (dis['Возраст'] < 7)].loc[:, p]) - a
    c = hlth[(hlth['Возраст'] >= 3) & (hlth['Возраст'] < 7)].loc[:, p].sum()
    d = len(hlth[(hlth['Возраст'] >= 3) & (hlth['Возраст'] < 7)].loc[:, p]) - c
          
    if 0 not in [a, b, c, d]:
        res = [int(i) for i  in [a, b, c, d]] + [odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
        anamn_df.loc[p] = res
    else:        
        anamn_df.loc[p] = [int(i) for i in [a, b, c, d]] + ['', '', '']

        
# variables with value only "1", older than 7

for p in cat_param_7:
    # replace str elements with 1
    for i in range(len(dis.loc[:, p])):
        if type(dis.loc[i, p]) == str:
            dis.loc[i, p] = 1
    for i in range(len(hlth.loc[:, p])):
        if type(hlth.loc[i, p]) == str:            
            hlth.loc[i, p] = 1
    
    a = dis[dis['Возраст'] >= 7].loc[:, p].sum()
    b = len(dis[dis['Возраст'] >= 7].loc[:, p]) - a
    c = hlth[hlth['Возраст'] >= 7].loc[:, p].sum()
    d = len(hlth[hlth['Возраст'] >= 7].loc[:, p]) - c
        
    if 0 not in [a, b, c, d]:
        res = [int(i) for i  in [a, b, c, d]] + [odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
        anamn_df.loc[p] = res
    else:
        anamn_df.loc[p] = [int(i) for i in [a, b, c, d]] + ['', '', '']

# %%
anamn_df
# Out:
#                                             Реконвалесценты – да  \
# анемия <3                                                     21
# неврологическая патология (тики, энурез) <3                   13
# ОРВИ <3                                                       28
# аллергические заболевания <3                                  11
# аденоиды <3                                                    2
# ангина <3                                                      5
# трахеиты, бронхиты <3                                         10
# кишечные инфекции <3                                          14
# другое <3                                                      5
# анемия <7                                                      0
# неврологическая патология (тики, энурез) <7                    0
# ОРВИ <7                                                       18
# аллергические заболевания <7                                   2
# аденоиды <7                                                    1
# ангина <7                                                      1
# трахеиты, бронхиты <7                                          5
# кишечные инфекции <7                                           3
# другое <7                                                      0
# анемия >7                                                      8
# неврологическая патология (тики, энурез) >7                    3
# ОРВИ >7                                                       63
# аллергические заболевания >7                                  11
# аденоиды >7                                                    3
# ангина >7                                                      8
# трахеиты, бронхиты >7                                         41
# кишечные инфекции >7                                          11
# другое >7                                                      3
#
#                                             Реконвалесценты – нет  \
# анемия <3                                                     180
# неврологическая патология (тики, энурез) <3                   188
# ОРВИ <3                                                       173
# аллергические заболевания <3                                  190
# аденоиды <3                                                   199
# ангина <3                                                     196
# трахеиты, бронхиты <3                                         191
# кишечные инфекции <3                                          187
# другое <3                                                     196
# анемия <7                                                      29
# неврологическая патология (тики, энурез) <7                    29
# ОРВИ <7                                                        11
# аллергические заболевания <7                                   27
# аденоиды <7                                                    28
# ангина <7                                                      28
# трахеиты, бронхиты <7                                          24
# кишечные инфекции <7                                           26
# другое <7                                                      29
# анемия >7                                                     140
# неврологическая патология (тики, энурез) >7                   145
# ОРВИ >7                                                        85
# аллергические заболевания >7                                  137
# аденоиды >7                                                   145
# ангина >7                                                     140
# трахеиты, бронхиты >7                                         107
# кишечные инфекции >7                                          137
# другое >7                                                     145
#
#                                             Неболевшие – да Неболевшие – нет  \
# анемия <3                                                 6               56
# неврологическая патология (тики, энурез) <3               3               59
# ОРВИ <3                                                  16               46
# аллергические заболевания <3                              7               55
# аденоиды <3                                               2               60
# ангина <3                                                 4               58
# трахеиты, бронхиты <3                                     9               53
# кишечные инфекции <3                                      5               57
# другое <3                                                 1               61
# анемия <7                                                 0               15
# неврологическая патология (тики, энурез) <7               0               15
# ОРВИ <7                                                   9                6
# аллергические заболевания <7                              1               14
# аденоиды <7                                               0               15
# ангина <7                                                 2               13
# трахеиты, бронхиты <7                                     5               10
# кишечные инфекции <7                                      3               12
# другое <7                                                 0               15
# анемия >7                                                 2               41
# неврологическая патология (тики, энурез) >7               0               43
# ОРВИ >7                                                  22               21
# аллергические заболевания >7                              2               41
# аденоиды >7                                               0               43
# ангина >7                                                 4               39
# трахеиты, бронхиты >7                                     7               36
# кишечные инфекции >7                                      2               41
# другое >7                                                 0               43
#
#                                                         OR (CI95) Хи-квадрат  \
# анемия <3                                     1.09 (CI 0.42–2.83)       0.03
# неврологическая патология (тики, энурез) <3   1.36 (CI 0.37–4.94)       0.22
# ОРВИ <3                                       0.47 (CI 0.23–0.93)        4.8
# аллергические заболевания <3                  0.45 (CI 0.17–1.23)       2.52
# аденоиды <3                                    0.3 (CI 0.04–2.19)       1.57
# ангина <3                                      0.37 (CI 0.1–1.42)       2.25
# трахеиты, бронхиты <3                          0.31 (CI 0.12–0.8)       6.44
# кишечные инфекции <3                          0.85 (CI 0.29–2.47)       0.09
# другое <3                                    1.56 (CI 0.18–13.58)       0.16
# анемия <7
# неврологическая патология (тики, энурез) <7
# ОРВИ <7                                        1.09 (CI 0.3–3.91)       0.02
# аллергические заболевания <7                 1.04 (CI 0.09–12.46)        0.0
# аденоиды <7
# ангина <7                                      0.23 (CI 0.02–2.8)       1.52
# трахеиты, бронхиты <7                          0.42 (CI 0.1–1.76)       1.46
# кишечные инфекции <7                          0.46 (CI 0.08–2.63)       0.78
# другое <7
# анемия >7                                     1.17 (CI 0.24–5.73)       0.04
# неврологическая патология (тики, энурез) >7
# ОРВИ >7                                        0.71 (CI 0.36–1.4)        1.0
# аллергические заболевания >7                  1.65 (CI 0.35–7.73)       0.41
# аденоиды >7
# ангина >7                                     0.56 (CI 0.16–1.95)       0.86
# трахеиты, бронхиты >7                         1.97 (CI 0.81–4.78)       2.31
# кишечные инфекции >7                          1.65 (CI 0.35–7.73)       0.41
# другое >7
#
#                                             p-value
# анемия <3                                     0.861
# неврологическая патология (тики, энурез) <3   0.639
# ОРВИ <3                                       0.029
# аллергические заболевания <3                  0.113
# аденоиды <3                                    0.21
# ангина <3                                     0.133
# трахеиты, бронхиты <3                         0.011
# кишечные инфекции <3                           0.77
# другое <3                                     0.687
# анемия <7
# неврологическая патология (тики, энурез) <7
# ОРВИ <7                                       0.894
# аллергические заболевания <7                  0.977
# аденоиды <7
# ангина <7                                     0.218
# трахеиты, бронхиты <7                         0.227
# кишечные инфекции <7                          0.376
# другое <7
# анемия >7                                     0.845
# неврологическая патология (тики, энурез) >7
# ОРВИ >7                                       0.318
# аллергические заболевания >7                  0.524
# аденоиды >7
# ангина >7                                     0.354
# трахеиты, бронхиты >7                         0.128
# кишечные инфекции >7                          0.524
# другое >7

# %% [markdown]
# Пол и образование

# %%
cat_cols = ['Реконвалесценты – да', 'Реконвалесценты – нет', 'Неболевшие – да', 'Неболевшие – нет', 'OR (CI95)', 'Хи-квадрат', 'p-value']
sex_df = pd.DataFrame(columns=cat_cols)


# Patient's sex

for p in cat_param_male:
    a = dis[dis[p] == 'муж'].loc[:, p].count()
    b = len(dis.loc[:, p]) - a
    c = hlth[hlth[p] == 'муж'].loc[:, p].count()
    d = len(hlth.loc[:, p]) - c
    sex_df.loc[p] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]

    
# Patient's education
    
for p in cat_param_edu:
     # replace str elements with 1
    for i in range(len(dis.loc[:, p])):
        if type(dis.loc[i, p]) == str:
            dis.loc[i, p] = 1
    for i in range(len(hlth.loc[:, p])):
        if type(hlth.loc[i, p]) == str:            
            hlth.loc[i, p] = 1
    
    a = dis.loc[:, p].sum()
    b = len(dis.loc[:, p]) - a
    c = hlth.loc[:, p].sum()
    d = len(hlth.loc[:, p]) - c
    sex_df.loc[p] = [int(i) for i  in [a, b, c, d]] + [odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
# Out:
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   o_r = (a / b) / (c / d)  # odds ratio
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#   ci_low = np.exp(np.log(o_r) - 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # lower confidence interval
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   ci_low = np.exp(np.log(o_r) - 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # lower confidence interval
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:7: RuntimeWarning: divide by zero encountered in double_scalars
#   ci_up = np.exp(np.log(o_r) + 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # Upper confidence interval

# %%
sex_df
# Out:
#         Реконвалесценты – да Реконвалесценты – нет Неболевшие – да  \
# муж                       93                   108              30
#  ДДУ                      39                   162              19
# Школа                    138                    63              42
# Колледж                    9                   192               1
# Н/о                       15                   186               0
#
#         Неболевшие – нет             OR (CI95)  Хи-квадрат  p-value
# муж                   32   0.92 (CI 0.52–1.62)        0.09    0.770
#  ДДУ                  43   0.54 (CI 0.29–1.04)        3.48    0.062
# Школа                 20   1.04 (CI 0.57–1.92)        0.02    0.892
# Колледж               61  2.86 (CI 0.36–23.03)        1.06    0.303
# Н/о                   62      inf (CI nan–inf)        4.91    0.027

# %%
cat_cols = ['Реконвалесценты – да', 'Реконвалесценты – нет', 'Неболевшие – да', 'Неболевшие – нет', 'OR (CI95)', 'Хи-квадрат', 'p-value']
yn_df = pd.DataFrame(columns=cat_cols)


# variables with value only "да"
for p in cat_param_y:
    a = dis[dis[p] == 'да'].loc[:, p].count()
    b = len(dis.loc[:, p]) - a
    c = hlth[hlth[p] == 'да'].loc[:, p].count()
    d = len(hlth.loc[:, p]) - c
    yn_df.loc[p] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]

# variables with values "да" and "нет"
for p in cat_param_yn:
    a = dis[dis[p] == 'да'].loc[:, p].count()
    b = dis[dis[p] == 'нет'].loc[:, p].count()
    c = hlth[hlth[p] == 'да'].loc[:, p].count()
    d = hlth[hlth[p] == 'нет'].loc[:, p].count()
    yn_df.loc[p] = yn_df.loc[p] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]

# %%
yn_df
# Out:
#                                                    Реконвалесценты – да  \
# Осложнения при беременности                                         103
# Болезни матери во время беременности                                 69
# Осложнения в родах                                                   26
# Принимал ли ваш ребенок витамин D                                   193
# Были клинические симптомы COVID-19 у ребенка                        182
# Находился ли ребенок на карантине из-за COVID-19                    167
# Принимал ли ваш ребенок поливитамины в 2020-202...                  156
# Болел ли кто-то из в 2020-2021 членов семьи или...                  179
# Посещал ли в 2020-21 годах ребенок зарубежные с...                   12
#
#                                                    Реконвалесценты – нет  \
# Осложнения при беременности                                           98
# Болезни матери во время беременности                                 132
# Осложнения в родах                                                   175
# Принимал ли ваш ребенок витамин D                                      8
# Были клинические симптомы COVID-19 у ребенка                          19
# Находился ли ребенок на карантине из-за COVID-19                      34
# Принимал ли ваш ребенок поливитамины в 2020-202...                    29
# Болел ли кто-то из в 2020-2021 членов семьи или...                     1
# Посещал ли в 2020-21 годах ребенок зарубежные с...                    26
#
#                                                    Неболевшие – да  \
# Осложнения при беременности                                     15
# Болезни матери во время беременности                            15
# Осложнения в родах                                               9
# Принимал ли ваш ребенок витамин D                               58
# Были клинические симптомы COVID-19 у ребенка                    23
# Находился ли ребенок на карантине из-за COVID-19                 7
# Принимал ли ваш ребенок поливитамины в 2020-202...              51
# Болел ли кто-то из в 2020-2021 членов семьи или...              61
# Посещал ли в 2020-21 годах ребенок зарубежные с...               2
#
#                                                    Неболевшие – нет  \
# Осложнения при беременности                                      47
# Болезни матери во время беременности                             47
# Осложнения в родах                                               53
# Принимал ли ваш ребенок витамин D                                 4
# Были клинические симптомы COVID-19 у ребенка                     39
# Находился ли ребенок на карантине из-за COVID-19                 55
# Принимал ли ваш ребенок поливитамины в 2020-202...                9
# Болел ли кто-то из в 2020-2021 членов семьи или...                1
# Посещал ли в 2020-21 годах ребенок зарубежные с...               58
#
#                                                                 OR (CI95)  \
# Осложнения при беременности                           3.29 (CI 1.73–6.27)
# Болезни матери во время беременности                  1.64 (CI 0.85–3.14)
# Осложнения в родах                                    0.87 (CI 0.39–1.98)
# Принимал ли ваш ребенок витамин D                     1.66 (CI 0.48–5.72)
# Были клинические симптомы COVID-19 у ребенка        16.24 (CI 8.07–32.68)
# Находился ли ребенок на карантине из-за COVID-19    38.59 (CI 16.19–92.0)
# Принимал ли ваш ребенок поливитамины в 2020-202...    0.95 (CI 0.42–2.14)
# Болел ли кто-то из в 2020-2021 членов семьи или...   2.93 (CI 0.18–47.63)
# Посещал ли в 2020-21 годах ребенок зарубежные с...  13.38 (CI 2.79–64.13)
#
#                                                     Хи-квадрат  p-value
# Осложнения при беременности                              14.02    0.000
# Болезни матери во время беременности                      2.24    0.135
# Осложнения в родах                                        0.10    0.749
# Принимал ли ваш ребенок витамин D                         0.66    0.415
# Были клинические симптомы COVID-19 у ребенка             78.75    0.000
# Находился ли ребенок на карантине из-за COVID-19        109.09    0.000
# Принимал ли ваш ребенок поливитамины в 2020-202...        0.02    0.900
# Болел ли кто-то из в 2020-2021 членов семьи или...        0.63    0.428
# Посещал ли в 2020-21 годах ребенок зарубежные с...       15.16    0.000

# %% [markdown]
# Роды

# %%
cat_cols = ['Реконвалесценты – да', 'Реконвалесценты – нет', 'Неболевшие – да', 'Неболевшие – нет', 'OR (CI95)', 'Хи-квадрат', 'p-value']
birth_df = pd.DataFrame(columns=cat_cols)

# Срок родов, 3 категории - "преждевременные", "запоздалые" или ничего
for p in cat_param_time:
    a = dis[dis[p] == 'преждевременные'].loc[:, p].count()
    b = len(dis.loc[:, p]) - a
    c = hlth[hlth[p] == 'преждевременные'].loc[:, p].count()
    d = len(hlth.loc[:, p]) - c
    birth_df.loc['Роды преждевременные'] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
    
for p in cat_param_time:
    a = dis[dis[p] == 'запоздалые'].loc[:, p].count()
    b = len(dis.loc[:, p]) - a
    c = hlth[hlth[p] == 'запоздалые'].loc[:, p].count()
    d = len(hlth.loc[:, p]) - c
    birth_df.loc['Роды запоздалые'] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]

for p in cat_param_time:
    a = dis[(dis[p] == 'преждевременные') | (dis[p] == 'запоздалые')].loc[:, p].count()
    b = len(dis.loc[:, p]) - a
    c = hlth[(hlth[p] == 'преждевременные') | (hlth[p] == 'запоздалые')].loc[:, p].count()
    d = len(hlth.loc[:, p]) - c
    birth_df.loc['Роды не в срок'] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]

# Родоразрешение "самопроизвольное" или "кесарево"
for p in cat_param_birt:
    a = dis[dis[p] == 'кесарево'].loc[:, p].count()
    b = dis[dis[p] == 'самопроизвольное'].loc[:, p].count()
    c = hlth[hlth[p] == 'кесарево'].loc[:, p].count()
    d = hlth[hlth[p] == 'самопроизвольное'].loc[:, p].count()
    birth_df.loc['Кесарево сечение'] = [a, b, c, d, odds_ratio([a, b], [c, d]), chi2_2x2([a, b], [c, d])[0], chi2_2x2([a, b], [c, d])[1]]
# Out:
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   o_r = (a / b) / (c / d)  # odds ratio
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:6: RuntimeWarning: divide by zero encountered in long_scalars
#   ci_low = np.exp(np.log(o_r) - 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # lower confidence interval
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   ci_low = np.exp(np.log(o_r) - 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # lower confidence interval
# C:\Users\ф\AppData\Local\Temp\ipykernel_17992\664778684.py:7: RuntimeWarning: divide by zero encountered in long_scalars
#   ci_up = np.exp(np.log(o_r) + 1.96 * np.sqrt(1 / a + 1 / b + 1 / c + 1/ d))  # Upper confidence interval

# %%
birth_df
# Out:
#                      Реконвалесценты – да Реконвалесценты – нет  \
# Роды преждевременные                   29                   172
# Роды запоздалые                         4                   197
# Роды не в срок                         33                   168
# Кесарево сечение                       47                   154
#
#                      Неболевшие – да Неболевшие – нет            OR (CI95)  \
# Роды преждевременные               7               55  1.32 (CI 0.55–3.19)
# Роды запоздалые                    0               62     inf (CI nan–inf)
# Роды не в срок                     7               55  1.54 (CI 0.65–3.69)
# Кесарево сечение                  10               52  1.59 (CI 0.75–3.36)
#
#                       Хи-квадрат  p-value
# Роды преждевременные        0.39    0.530
# Роды запоздалые             1.25    0.263
# Роды не в срок              0.97    0.326
# Кесарево сечение            1.47    0.226

# %%
## cat_param_y + cat_param_03 + cat_param_37 + cat_param_7 + cat_param_chr + cat_param_sym + cat_param_bas

for d in [cat_df, anamn_df, sex_df, yn_df, birth_df]:
    for i in range(len(d.index)):
        health = [d.iloc[i, 2], d.iloc[i, 3]]
        disease = [d.iloc[i, 0], d.iloc[i, 1]]
        plot_name = d.index[i]
        barplot(health, disease, plot_name)

# %% [markdown]
# ## Заготовка под график (барплот) для нескольких переменных

# %%
# Заготовка под график (барплот) для нескольких переменных

# тут нужен кастомизированный набор в зависимости от количества переменных n
h, d = [[25, 25], [30, 20], [20, 30]], [[60, 40], [90, 10], [50, 50]]

# пример для n = 3
x = ['Неболевшие1', 'Реконвалесценты1', 'Неболевшие2', 'Реконвалесценты2', 'Неболевшие3', 'Реконвалесценты3']
y1 = [[h[i][0], d[i][0]] for i in range(3)]  #  event
y2 = [[h[i][1], d[i][1]] for i in range(3)]  # no event

y1, y2 = list(chain(*y1)), list(chain(*y2))  # flattering of the list

fig, ax = plt.subplots()

ax.bar(x, y1, width=0.8)
ax.bar(x, y2, bottom = y1, width=0.8)

fig.set_figwidth(7)    #  ширина и
fig.set_figheight(4)    #  высота "Figure"
fig.set_facecolor('floralwhite')
ax.set_facecolor('seashell')
plt.legend(['event', 'no event'], loc='upper left')
plt.xticks(rotation=90)

plt.show()
